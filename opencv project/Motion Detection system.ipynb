# %%
#importing modules required for the project
import numpy as np
import pandas as pd
import cv2

# %%
#importing modules for saving snapshots
import os
import datetime

# Specify the path to the video file
video_file_path = "../../tennis_sample.mp4"

# Checks to see if the video file can be opened
cap = cv2.VideoCapture(video_file_path)
if not cap.isOpened():
    print("Error: Unable to open video file.")
    exit()

# Get the frame width and height
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create a window for displaying the video
cv2.namedWindow("Motion Detection", cv2.WINDOW_NORMAL)
cv2.resizeWindow("Motion Detection", width, height)

# Initialize frame buffer
buffer_size = 10
frame_buffer = []

# Main loop
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to grayscale and apply Gaussian blur
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (21, 21), 0)

    # Add the current frame to the frame buffer
    frame_buffer.append(blurred)
    if len(frame_buffer) > buffer_size:
        frame_buffer.pop(0)

    # Check for significant motion
    if len(frame_buffer) >= 5:
        diff = cv2.absdiff(frame_buffer[-1], frame_buffer[-4])
        thresh = cv2.threshold(diff, 20, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.dilate(thresh, None, iterations=2)

        # Use findContours properly (adjust indexing for your OpenCV version)
        contours, _ = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Draw bounding box for significant contours
        for contour in contours:
            if cv2.contourArea(contour) < 100:  # Adjust threshold as needed
                continue
            x, y, w, h = cv2.boundingRect(contour)
            print(f"Bounding Box: x={x}, y={y}, w={w}, h={h}")  # Debugging output

            if w > 20 and h > 20: 
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 4)

                # Save snapshot
                timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
                snapshot_path = f"snapshot_{timestamp}.jpg"
                cv2.imwrite(snapshot_path, frame)
                print(f"Snapshot saved: {snapshot_path}")

                # Printing alert message
                print("Motion detected!")

        #cv2.imshow("Motion Detection", thresh)

    cv2.imshow("Motion Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# Bounding Box: x=1837, y=626, w=15, h=10
# Bounding Box: x=1801, y=610, w=22, h=11
# Bounding Box: x=296, y=590, w=54, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-12.jpg
# Motion detected!
# Bounding Box: x=961, y=0, w=86, h=5
# Bounding Box: x=1806, y=612, w=16, h=9
# Bounding Box: x=297, y=587, w=53, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-12.jpg
# Motion detected!
# Bounding Box: x=961, y=0, w=65, h=5
# Bounding Box: x=1807, y=610, w=18, h=13
# Bounding Box: x=297, y=585, w=53, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-12.jpg
# Motion detected!
# Bounding Box: x=960, y=0, w=65, h=6
# Bounding Box: x=341, y=616, w=13, h=13
# Bounding Box: x=298, y=582, w=45, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-12.jpg
# Motion detected!
# Bounding Box: x=1812, y=610, w=15, h=12
# Bounding Box: x=299, y=579, w=46, h=49
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=962, y=0, w=45, h=5
# Bounding Box: x=1826, y=625, w=22, h=15
# Bounding Box: x=1815, y=610, w=13, h=12
# Bounding Box: x=299, y=575, w=60, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=1827, y=626, w=21, h=15
# Bounding Box: x=342, y=595, w=16, h=16
# Bounding Box: x=342, y=576, w=14, h=14
# Bounding Box: x=299, y=571, w=42, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=1833, y=631, w=18, h=10
# Bounding Box: x=299, y=568, w=43, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=1837, y=631, w=15, h=10
# Bounding Box: x=300, y=565, w=43, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=348, y=559, w=11, h=13
# Bounding Box: x=346, y=578, w=12, h=14
# Bounding Box: x=300, y=563, w=44, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=350, y=549, w=11, h=17
# Bounding Box: x=301, y=561, w=46, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=351, y=543, w=14, h=17
# Bounding Box: x=302, y=557, w=47, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=352, y=540, w=14, h=16
# Bounding Box: x=302, y=550, w=50, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=303, y=547, w=52, h=52
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=304, y=547, w=51, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=1811, y=605, w=13, h=15
# Bounding Box: x=305, y=545, w=50, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=1808, y=603, w=20, h=17
# Bounding Box: x=305, y=542, w=52, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=1807, y=601, w=21, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-13.jpg
# Motion detected!
# Bounding Box: x=306, y=539, w=60, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1806, y=599, w=21, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=357, y=578, w=12, h=12
# Bounding Box: x=306, y=536, w=54, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1802, y=597, w=25, h=27
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=358, y=572, w=12, h=13
# Bounding Box: x=346, y=556, w=16, h=31
# Bounding Box: x=307, y=534, w=50, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1799, y=595, w=27, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1814, y=580, w=13, h=13
# Bounding Box: x=347, y=566, w=10, h=16
# Bounding Box: x=307, y=531, w=57, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1810, y=611, w=14, h=14
# Bounding Box: x=307, y=528, w=62, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1809, y=613, w=14, h=18
# Bounding Box: x=308, y=525, w=52, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1810, y=618, w=15, h=16
# Bounding Box: x=308, y=521, w=53, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=308, y=517, w=60, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=1817, y=620, w=21, h=16
# Bounding Box: x=309, y=514, w=54, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=369, y=505, w=13, h=15
# Bounding Box: x=1815, y=621, w=23, h=15
# Bounding Box: x=310, y=510, w=62, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=369, y=500, w=14, h=16
# Bounding Box: x=1812, y=622, w=15, h=13
# Bounding Box: x=311, y=508, w=59, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=312, y=505, w=56, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-14.jpg
# Motion detected!
# Bounding Box: x=313, y=500, w=55, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=314, y=496, w=55, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=315, y=493, w=54, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=316, y=492, w=53, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=359, y=533, w=13, h=13
# Bounding Box: x=317, y=492, w=45, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=360, y=527, w=14, h=14
# Bounding Box: x=317, y=489, w=45, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=360, y=519, w=15, h=15
# Bounding Box: x=318, y=485, w=46, h=52
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=362, y=513, w=13, h=13
# Bounding Box: x=319, y=482, w=40, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=319, y=479, w=55, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=365, y=477, w=13, h=12
# Bounding Box: x=319, y=476, w=41, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=320, y=473, w=41, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=320, y=469, w=41, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=369, y=457, w=13, h=16
# Bounding Box: x=321, y=465, w=45, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=370, y=452, w=13, h=19
# Bounding Box: x=322, y=462, w=48, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=372, y=452, w=13, h=16
# Bounding Box: x=323, y=451, w=50, h=58
# Snapshot saved: snapshot_2025-04-02_19-03-15.jpg
# Motion detected!
# Bounding Box: x=323, y=455, w=50, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=324, y=451, w=49, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=324, y=448, w=50, h=51
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=323, y=445, w=52, h=49
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=363, y=489, w=9, h=15
# Bounding Box: x=324, y=443, w=53, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=363, y=466, w=15, h=33
# Bounding Box: x=324, y=441, w=51, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=364, y=462, w=15, h=32
# Bounding Box: x=325, y=438, w=52, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=365, y=471, w=11, h=17
# Bounding Box: x=325, y=436, w=60, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=366, y=469, w=11, h=13
# Bounding Box: x=325, y=434, w=51, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=1822, y=586, w=15, h=14
# Bounding Box: x=325, y=432, w=52, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=325, y=429, w=59, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=326, y=426, w=53, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=326, y=413, w=69, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=327, y=420, w=61, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-16.jpg
# Motion detected!
# Bounding Box: x=1814, y=614, w=11, h=12
# Bounding Box: x=328, y=416, w=52, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1798, y=601, w=28, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=329, y=412, w=50, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1801, y=602, w=24, h=18
# Bounding Box: x=330, y=408, w=51, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1805, y=604, w=21, h=15
# Bounding Box: x=331, y=404, w=51, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1806, y=604, w=21, h=16
# Bounding Box: x=332, y=401, w=51, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1809, y=605, w=17, h=14
# Bounding Box: x=374, y=442, w=11, h=13
# Bounding Box: x=332, y=397, w=55, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=373, y=406, w=16, h=11
# Bounding Box: x=332, y=394, w=40, h=58
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=333, y=391, w=38, h=55
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=333, y=388, w=38, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1809, y=608, w=12, h=13
# Bounding Box: x=373, y=417, w=12, h=13
# Bounding Box: x=332, y=385, w=40, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=374, y=390, w=14, h=12
# Bounding Box: x=332, y=382, w=40, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=332, y=379, w=41, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=333, y=377, w=40, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-17.jpg
# Motion detected!
# Bounding Box: x=1851, y=615, w=12, h=12
# Bounding Box: x=333, y=375, w=40, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1850, y=614, w=13, h=13
# Bounding Box: x=333, y=372, w=54, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1840, y=612, w=23, h=26
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1802, y=609, w=13, h=11
# Bounding Box: x=334, y=370, w=47, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1840, y=627, w=18, h=10
# Bounding Box: x=1841, y=609, w=22, h=17
# Bounding Box: x=1802, y=607, w=15, h=12
# Bounding Box: x=335, y=368, w=47, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1838, y=607, w=24, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=335, y=365, w=49, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1824, y=606, w=38, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=335, y=362, w=50, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1822, y=606, w=40, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=336, y=359, w=50, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1821, y=606, w=42, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=373, y=399, w=10, h=15
# Bounding Box: x=336, y=357, w=50, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1820, y=606, w=43, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=373, y=393, w=10, h=16
# Bounding Box: x=376, y=379, w=11, h=13
# Bounding Box: x=337, y=354, w=50, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1819, y=605, w=43, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=338, y=351, w=52, h=54
# Snapshot saved: snapshot_2025-04-02_19-03-18.jpg
# Motion detected!
# Bounding Box: x=1818, y=604, w=43, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1802, y=601, w=16, h=11
# Bounding Box: x=375, y=384, w=10, h=16
# Bounding Box: x=338, y=348, w=54, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1817, y=604, w=43, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1799, y=599, w=18, h=14
# Bounding Box: x=376, y=381, w=11, h=13
# Bounding Box: x=338, y=346, w=55, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1817, y=604, w=42, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1797, y=598, w=19, h=15
# Bounding Box: x=339, y=343, w=48, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1826, y=603, w=32, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1795, y=597, w=20, h=16
# Bounding Box: x=380, y=370, w=11, h=12
# Bounding Box: x=339, y=340, w=49, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1825, y=602, w=32, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1792, y=597, w=21, h=18
# Bounding Box: x=340, y=337, w=52, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1823, y=602, w=32, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1789, y=595, w=21, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=341, y=334, w=47, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1822, y=602, w=31, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1785, y=594, w=22, h=20
# Bounding Box: x=390, y=345, w=13, h=14
# Bounding Box: x=342, y=332, w=46, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1820, y=601, w=33, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1780, y=592, w=24, h=19
# Bounding Box: x=343, y=330, w=46, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1814, y=595, w=38, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1775, y=590, w=28, h=18
# Bounding Box: x=344, y=328, w=47, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-19.jpg
# Motion detected!
# Bounding Box: x=1784, y=593, w=18, h=15
# Bounding Box: x=1811, y=592, w=40, h=37
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=345, y=326, w=47, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1824, y=599, w=25, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1780, y=591, w=19, h=16
# Bounding Box: x=1808, y=590, w=19, h=22
# Bounding Box: x=346, y=324, w=39, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1827, y=599, w=20, h=20
# Bounding Box: x=1775, y=590, w=23, h=17
# Bounding Box: x=346, y=322, w=40, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1826, y=599, w=20, h=21
# Bounding Box: x=1781, y=598, w=15, h=10
# Bounding Box: x=347, y=321, w=40, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1783, y=600, w=14, h=10
# Bounding Box: x=1824, y=599, w=22, h=27
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=348, y=319, w=40, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1824, y=599, w=21, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=348, y=317, w=39, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1824, y=599, w=20, h=21
# Bounding Box: x=348, y=315, w=37, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1823, y=598, w=19, h=20
# Bounding Box: x=349, y=313, w=36, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1823, y=598, w=19, h=21
# Bounding Box: x=349, y=312, w=37, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1824, y=598, w=11, h=16
# Bounding Box: x=349, y=310, w=37, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1824, y=598, w=10, h=15
# Bounding Box: x=350, y=308, w=35, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=1792, y=608, w=12, h=12
# Bounding Box: x=350, y=307, w=46, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-20.jpg
# Motion detected!
# Bounding Box: x=350, y=305, w=39, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=351, y=303, w=38, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=351, y=322, w=37, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=355, y=302, w=25, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=352, y=300, w=34, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=352, y=319, w=33, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=356, y=299, w=22, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=353, y=299, w=31, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-21.jpg
# Motion detected!
# Bounding Box: x=355, y=319, w=28, h=17
# Bounding Box: x=356, y=298, w=18, h=18
# Bounding Box: x=357, y=319, w=24, h=15
# Bounding Box: x=356, y=298, w=16, h=17
# Bounding Box: x=358, y=318, w=21, h=15
# Bounding Box: x=1823, y=601, w=11, h=14
# Bounding Box: x=1811, y=599, w=10, h=13
# Bounding Box: x=1779, y=592, w=13, h=19
# Bounding Box: x=1823, y=601, w=12, h=14
# Bounding Box: x=1811, y=598, w=11, h=14
# Bounding Box: x=1781, y=593, w=12, h=16
# Bounding Box: x=1824, y=600, w=12, h=16
# Bounding Box: x=1811, y=598, w=12, h=16
# Bounding Box: x=1784, y=593, w=11, h=15
# Bounding Box: x=1812, y=598, w=25, h=18
# Bounding Box: x=1813, y=598, w=25, h=18
# Bounding Box: x=1814, y=598, w=26, h=18
# Bounding Box: x=1815, y=598, w=27, h=19
# Bounding Box: x=1815, y=598, w=28, h=20
# Bounding Box: x=1817, y=599, w=27, h=19
# Bounding Box: x=1818, y=599, w=27, h=19
# Bounding Box: x=1819, y=599, w=27, h=19
# Bounding Box: x=1821, y=599, w=26, h=19
# Bounding Box: x=1822, y=600, w=26, h=17
# Bounding Box: x=1823, y=600, w=26, h=18
# Bounding Box: x=1810, y=606, w=13, h=16
# Bounding Box: x=1824, y=600, w=25, h=17
# Bounding Box: x=1811, y=605, w=13, h=17
# Bounding Box: x=1826, y=600, w=15, h=17
# Bounding Box: x=1812, y=605, w=15, h=17
# Bounding Box: x=1827, y=600, w=15, h=16
# Bounding Box: x=1813, y=604, w=14, h=18
# Bounding Box: x=1828, y=600, w=15, h=16
# Bounding Box: x=1829, y=600, w=14, h=16
# Bounding Box: x=1796, y=604, w=15, h=10
# Bounding Box: x=1831, y=601, w=13, h=14
# Bounding Box: x=1797, y=602, w=16, h=11
# Bounding Box: x=1832, y=601, w=12, h=13
# Bounding Box: x=1799, y=602, w=14, h=10
# Bounding Box: x=1780, y=599, w=14, h=11
# Bounding Box: x=1775, y=597, w=20, h=18
# Bounding Box: x=1799, y=590, w=19, h=10
# Bounding Box: x=1775, y=596, w=21, h=19
# Bounding Box: x=1798, y=590, w=19, h=10
# Bounding Box: x=1776, y=594, w=21, h=20
# Bounding Box: x=1798, y=590, w=18, h=9
# Bounding Box: x=347, y=312, w=11, h=20
# Bounding Box: x=1777, y=589, w=33, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=348, y=312, w=11, h=22
# Bounding Box: x=1779, y=588, w=30, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=348, y=310, w=14, h=26
# Bounding Box: x=1781, y=587, w=28, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=348, y=308, w=30, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=1782, y=587, w=26, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=349, y=307, w=31, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=1784, y=585, w=26, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-22.jpg
# Motion detected!
# Bounding Box: x=350, y=306, w=38, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1785, y=584, w=24, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=351, y=305, w=38, h=33
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1787, y=583, w=24, h=20
# Bounding Box: x=352, y=304, w=41, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1822, y=606, w=17, h=9
# Bounding Box: x=1788, y=581, w=24, h=12
# Bounding Box: x=354, y=304, w=40, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1821, y=605, w=19, h=9
# Bounding Box: x=1800, y=579, w=26, h=10
# Bounding Box: x=355, y=303, w=40, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1821, y=604, w=18, h=10
# Bounding Box: x=1799, y=577, w=20, h=11
# Bounding Box: x=357, y=303, w=38, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1815, y=592, w=23, h=20
# Bounding Box: x=1799, y=573, w=20, h=14
# Bounding Box: x=358, y=302, w=38, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1814, y=588, w=22, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1800, y=569, w=16, h=19
# Bounding Box: x=360, y=302, w=37, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1798, y=564, w=38, h=37
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=388, y=329, w=12, h=12
# Bounding Box: x=362, y=302, w=36, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1798, y=561, w=41, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=363, y=302, w=35, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1799, y=559, w=46, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=365, y=302, w=33, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=1800, y=559, w=38, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-23.jpg
# Motion detected!
# Bounding Box: x=367, y=303, w=31, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=1803, y=560, w=34, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=369, y=304, w=32, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=1806, y=587, w=15, h=13
# Bounding Box: x=1807, y=560, w=33, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=388, y=339, w=16, h=15
# Bounding Box: x=382, y=307, w=14, h=26
# Bounding Box: x=370, y=304, w=14, h=26
# Bounding Box: x=1805, y=560, w=32, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=384, y=334, w=23, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=382, y=316, w=15, h=17
# Bounding Box: x=371, y=303, w=15, h=26
# Bounding Box: x=1839, y=563, w=12, h=12
# Bounding Box: x=1814, y=559, w=22, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=385, y=335, w=26, h=26
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=383, y=318, w=14, h=15
# Bounding Box: x=372, y=303, w=16, h=24
# Bounding Box: x=1799, y=575, w=14, h=13
# Bounding Box: x=1845, y=564, w=11, h=12
# Bounding Box: x=1815, y=563, w=25, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=382, y=318, w=34, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=373, y=303, w=16, h=24
# Bounding Box: x=1122, y=1075, w=112, h=5
# Bounding Box: x=1796, y=574, w=17, h=14
# Bounding Box: x=1849, y=564, w=13, h=12
# Bounding Box: x=1814, y=563, w=32, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=405, y=352, w=14, h=11
# Bounding Box: x=391, y=339, w=12, h=16
# Bounding Box: x=381, y=320, w=19, h=19
# Bounding Box: x=374, y=303, w=17, h=20
# Bounding Box: x=542, y=1076, w=57, h=4
# Bounding Box: x=1112, y=1075, w=123, h=5
# Bounding Box: x=1794, y=573, w=18, h=15
# Bounding Box: x=1854, y=565, w=13, h=12
# Bounding Box: x=1815, y=564, w=37, h=26
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=381, y=321, w=20, h=20
# Bounding Box: x=375, y=304, w=16, h=20
# Bounding Box: x=1833, y=596, w=14, h=10
# Bounding Box: x=1787, y=573, w=23, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=1825, y=566, w=17, h=15
# Bounding Box: x=1859, y=565, w=12, h=13
# Bounding Box: x=380, y=322, w=21, h=20
# Bounding Box: x=375, y=304, w=19, h=20
# Bounding Box: x=1831, y=594, w=16, h=13
# Bounding Box: x=1786, y=572, w=23, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=1863, y=566, w=12, h=12
# Bounding Box: x=379, y=323, w=22, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=376, y=304, w=19, h=20
# Bounding Box: x=1831, y=594, w=20, h=15
# Bounding Box: x=1777, y=571, w=31, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=1867, y=567, w=11, h=12
# Bounding Box: x=379, y=324, w=22, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-24.jpg
# Motion detected!
# Bounding Box: x=376, y=305, w=20, h=20
# Bounding Box: x=1815, y=593, w=37, h=16
# Bounding Box: x=1810, y=581, w=18, h=12
# Bounding Box: x=1774, y=570, w=33, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1859, y=566, w=23, h=13
# Bounding Box: x=379, y=325, w=22, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=377, y=306, w=19, h=20
# Bounding Box: x=1811, y=591, w=41, h=18
# Bounding Box: x=1809, y=575, w=20, h=18
# Bounding Box: x=1772, y=569, w=36, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1863, y=566, w=21, h=13
# Bounding Box: x=380, y=327, w=21, h=20
# Bounding Box: x=377, y=308, w=18, h=18
# Bounding Box: x=1867, y=568, w=20, h=12
# Bounding Box: x=1770, y=567, w=82, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=380, y=328, w=21, h=20
# Bounding Box: x=378, y=309, w=16, h=17
# Bounding Box: x=1870, y=569, w=19, h=12
# Bounding Box: x=1768, y=566, w=83, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=380, y=329, w=22, h=20
# Bounding Box: x=379, y=310, w=14, h=16
# Bounding Box: x=1873, y=570, w=17, h=11
# Bounding Box: x=1779, y=566, w=72, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=381, y=331, w=20, h=19
# Bounding Box: x=379, y=312, w=13, h=15
# Bounding Box: x=1784, y=565, w=65, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1782, y=564, w=66, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1781, y=563, w=65, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1780, y=562, w=65, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1819, y=585, w=24, h=19
# Bounding Box: x=1780, y=561, w=40, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1818, y=586, w=24, h=18
# Bounding Box: x=1780, y=560, w=36, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1817, y=586, w=22, h=17
# Bounding Box: x=1781, y=560, w=33, h=27
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1816, y=586, w=22, h=17
# Bounding Box: x=1781, y=559, w=36, h=27
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1797, y=586, w=12, h=13
# Bounding Box: x=1815, y=584, w=21, h=18
# Bounding Box: x=1782, y=559, w=37, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-25.jpg
# Motion detected!
# Bounding Box: x=1814, y=582, w=22, h=20
# Bounding Box: x=1871, y=574, w=18, h=10
# Bounding Box: x=1781, y=556, w=38, h=27
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1813, y=578, w=24, h=17
# Bounding Box: x=1868, y=574, w=19, h=11
# Bounding Box: x=1782, y=553, w=38, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1781, y=550, w=55, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1787, y=548, w=47, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1786, y=546, w=47, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1820, y=585, w=13, h=13
# Bounding Box: x=1865, y=574, w=11, h=12
# Bounding Box: x=1791, y=544, w=46, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1816, y=579, w=28, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1786, y=542, w=52, h=51
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1778, y=540, w=64, h=70
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1778, y=558, w=69, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1802, y=537, w=34, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1831, y=597, w=13, h=15
# Bounding Box: x=1774, y=555, w=54, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1818, y=533, w=18, h=31
# Bounding Box: x=1829, y=583, w=14, h=28
# Bounding Box: x=1773, y=555, w=63, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1817, y=530, w=19, h=30
# Bounding Box: x=1768, y=556, w=79, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1811, y=527, w=25, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1765, y=556, w=77, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-26.jpg
# Motion detected!
# Bounding Box: x=1812, y=523, w=23, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1782, y=576, w=26, h=20
# Bounding Box: x=1816, y=573, w=21, h=17
# Bounding Box: x=1765, y=549, w=55, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1809, y=522, w=25, h=28
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=978, y=0, w=34, h=5
# Bounding Box: x=1765, y=554, w=57, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1807, y=521, w=26, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=972, y=0, w=83, h=5
# Bounding Box: x=1764, y=549, w=51, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1805, y=522, w=26, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=970, y=0, w=86, h=6
# Bounding Box: x=1763, y=547, w=52, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1804, y=523, w=23, h=16
# Bounding Box: x=970, y=0, w=84, h=6
# Bounding Box: x=1766, y=554, w=16, h=14
# Bounding Box: x=1769, y=544, w=50, h=54
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1804, y=520, w=21, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=972, y=0, w=80, h=6
# Bounding Box: x=1780, y=521, w=45, h=77
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1062, y=0, w=23, h=6
# Bounding Box: x=972, y=0, w=79, h=6
# Bounding Box: x=1783, y=522, w=42, h=75
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=983, y=0, w=67, h=5
# Bounding Box: x=1782, y=524, w=42, h=71
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1779, y=527, w=44, h=69
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1796, y=599, w=15, h=17
# Bounding Box: x=1779, y=530, w=42, h=67
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1087, y=478, w=12, h=20
# Bounding Box: x=404, y=333, w=13, h=12
# Bounding Box: x=1779, y=533, w=38, h=62
# Snapshot saved: snapshot_2025-04-02_19-03-27.jpg
# Motion detected!
# Bounding Box: x=1087, y=453, w=12, h=66
# Bounding Box: x=402, y=335, w=14, h=12
# Bounding Box: x=1780, y=535, w=37, h=54
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1088, y=430, w=9, h=56
# Bounding Box: x=401, y=331, w=19, h=16
# Bounding Box: x=1797, y=601, w=14, h=15
# Bounding Box: x=1776, y=538, w=41, h=58
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1088, y=481, w=12, h=15
# Bounding Box: x=1088, y=411, w=9, h=36
# Bounding Box: x=402, y=331, w=18, h=16
# Bounding Box: x=1766, y=542, w=51, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1087, y=455, w=12, h=62
# Bounding Box: x=1746, y=561, w=14, h=10
# Bounding Box: x=1760, y=547, w=56, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1087, y=431, w=10, h=55
# Bounding Box: x=1743, y=551, w=72, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1088, y=408, w=12, h=77
# Bounding Box: x=1743, y=553, w=71, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1090, y=534, w=9, h=103
# Bounding Box: x=1089, y=381, w=10, h=99
# Bounding Box: x=1743, y=554, w=68, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1090, y=377, w=9, h=55
# Bounding Box: x=378, y=328, w=28, h=13
# Bounding Box: x=387, y=312, w=14, h=11
# Bounding Box: x=1761, y=556, w=47, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=377, y=329, w=29, h=13
# Bounding Box: x=383, y=312, w=21, h=15
# Bounding Box: x=1792, y=565, w=12, h=15
# Bounding Box: x=1751, y=555, w=41, h=33
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=377, y=330, w=30, h=14
# Bounding Box: x=381, y=312, w=24, h=17
# Bounding Box: x=1746, y=551, w=59, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=377, y=331, w=30, h=14
# Bounding Box: x=381, y=313, w=29, h=16
# Bounding Box: x=1761, y=553, w=45, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1749, y=547, w=14, h=11
# Bounding Box: x=382, y=352, w=11, h=12
# Bounding Box: x=377, y=332, w=30, h=14
# Bounding Box: x=381, y=314, w=32, h=16
# Bounding Box: x=1763, y=550, w=45, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=377, y=333, w=26, h=13
# Bounding Box: x=382, y=315, w=32, h=17
# Bounding Box: x=1764, y=548, w=49, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1731, y=533, w=16, h=12
# Bounding Box: x=377, y=334, w=23, h=13
# Bounding Box: x=392, y=316, w=22, h=18
# Bounding Box: x=1767, y=551, w=47, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-28.jpg
# Motion detected!
# Bounding Box: x=1763, y=541, w=15, h=10
# Bounding Box: x=1736, y=529, w=17, h=13
# Bounding Box: x=379, y=335, w=18, h=10
# Bounding Box: x=1767, y=550, w=49, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1768, y=540, w=13, h=11
# Bounding Box: x=1741, y=527, w=16, h=12
# Bounding Box: x=1768, y=549, w=50, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1746, y=525, w=13, h=13
# Bounding Box: x=1760, y=540, w=60, h=55
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1761, y=551, w=61, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1760, y=559, w=30, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1788, y=552, w=36, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1761, y=559, w=31, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1793, y=553, w=32, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=375, y=318, w=23, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1759, y=554, w=67, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=373, y=317, w=24, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1749, y=555, w=77, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=373, y=315, w=23, h=26
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1751, y=553, w=77, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=372, y=314, w=25, h=33
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1804, y=574, w=17, h=25
# Bounding Box: x=1752, y=545, w=78, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=371, y=312, w=27, h=37
# Snapshot saved: snapshot_2025-04-02_19-03-29.jpg
# Motion detected!
# Bounding Box: x=1806, y=576, w=18, h=26
# Bounding Box: x=1754, y=548, w=77, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=378, y=336, w=26, h=12
# Bounding Box: x=371, y=311, w=27, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=1810, y=580, w=14, h=23
# Bounding Box: x=1758, y=548, w=75, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=377, y=335, w=28, h=13
# Bounding Box: x=370, y=310, w=28, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=1811, y=579, w=15, h=24
# Bounding Box: x=1799, y=553, w=35, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=1764, y=546, w=44, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=377, y=334, w=29, h=12
# Bounding Box: x=370, y=308, w=28, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=1812, y=580, w=14, h=21
# Bounding Box: x=1794, y=580, w=17, h=10
# Bounding Box: x=1804, y=558, w=31, h=20
# Bounding Box: x=1765, y=547, w=36, h=28
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=377, y=332, w=29, h=13
# Bounding Box: x=369, y=307, w=29, h=19
# Bounding Box: x=1811, y=579, w=15, h=12
# Bounding Box: x=1768, y=551, w=34, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=376, y=326, w=35, h=19
# Bounding Box: x=369, y=306, w=29, h=19
# Bounding Box: x=1771, y=553, w=32, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=376, y=324, w=36, h=20
# Bounding Box: x=369, y=305, w=28, h=18
# Bounding Box: x=1775, y=554, w=29, h=20
# Bounding Box: x=377, y=319, w=39, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=369, y=304, w=28, h=18
# Bounding Box: x=1812, y=590, w=12, h=13
# Bounding Box: x=1794, y=558, w=11, h=17
# Bounding Box: x=376, y=319, w=40, h=20
# Bounding Box: x=369, y=303, w=27, h=18
# Bounding Box: x=1811, y=589, w=13, h=13
# Bounding Box: x=1781, y=557, w=25, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=377, y=322, w=30, h=16
# Bounding Box: x=368, y=302, w=26, h=18
# Bounding Box: x=1809, y=589, w=14, h=12
# Bounding Box: x=1777, y=558, w=30, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-30.jpg
# Motion detected!
# Bounding Box: x=380, y=320, w=27, h=15
# Bounding Box: x=369, y=302, w=24, h=16
# Bounding Box: x=1803, y=584, w=17, h=16
# Bounding Box: x=1771, y=575, w=16, h=13
# Bounding Box: x=1788, y=561, w=19, h=21
# Bounding Box: x=369, y=302, w=22, h=15
# Bounding Box: x=1801, y=582, w=17, h=16
# Bounding Box: x=1790, y=562, w=17, h=19
# Bounding Box: x=369, y=302, w=20, h=14
# Bounding Box: x=1793, y=565, w=14, h=15
# Bounding Box: x=367, y=302, w=21, h=15
# Bounding Box: x=1772, y=575, w=13, h=12
# Bounding Box: x=1792, y=554, w=15, h=26
# Bounding Box: x=1791, y=555, w=19, h=24
# Bounding Box: x=399, y=332, w=15, h=14
# Bounding Box: x=1793, y=558, w=17, h=21
# Bounding Box: x=1795, y=561, w=16, h=16
# Bounding Box: x=1798, y=566, w=14, h=12
# Bounding Box: x=393, y=309, w=11, h=17
# Bounding Box: x=391, y=308, w=12, h=18
# Bounding Box: x=390, y=311, w=12, h=15
# Bounding Box: x=389, y=311, w=12, h=15
# Bounding Box: x=370, y=304, w=8, h=18
# Bounding Box: x=1810, y=571, w=11, h=12
# Bounding Box: x=1810, y=570, w=12, h=13
# Bounding Box: x=1823, y=564, w=16, h=18
# Bounding Box: x=1810, y=562, w=31, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1811, y=562, w=31, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1812, y=561, w=31, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1814, y=561, w=30, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1815, y=562, w=30, h=23
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1811, y=561, w=35, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1812, y=561, w=35, h=26
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1814, y=561, w=34, h=28
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=1821, y=562, w=29, h=27
# Snapshot saved: snapshot_2025-04-02_19-03-31.jpg
# Motion detected!
# Bounding Box: x=365, y=309, w=10, h=18
# Bounding Box: x=1803, y=568, w=49, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=365, y=307, w=11, h=21
# Bounding Box: x=1809, y=568, w=44, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=365, y=307, w=13, h=22
# Bounding Box: x=1812, y=568, w=42, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=366, y=307, w=13, h=22
# Bounding Box: x=1815, y=568, w=41, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=366, y=306, w=14, h=23
# Bounding Box: x=381, y=296, w=10, h=18
# Bounding Box: x=1804, y=569, w=53, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=367, y=306, w=14, h=23
# Bounding Box: x=1804, y=574, w=29, h=18
# Bounding Box: x=1833, y=569, w=26, h=20
# Bounding Box: x=367, y=305, w=15, h=24
# Bounding Box: x=382, y=294, w=12, h=19
# Bounding Box: x=1834, y=569, w=16, h=19
# Bounding Box: x=1803, y=563, w=17, h=11
# Bounding Box: x=368, y=305, w=15, h=23
# Bounding Box: x=383, y=294, w=22, h=20
# Bounding Box: x=1836, y=570, w=14, h=17
# Bounding Box: x=369, y=304, w=14, h=24
# Bounding Box: x=383, y=293, w=23, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=1823, y=582, w=15, h=9
# Bounding Box: x=1837, y=570, w=14, h=16
# Bounding Box: x=1785, y=570, w=18, h=15
# Bounding Box: x=370, y=303, w=15, h=24
# Bounding Box: x=384, y=293, w=22, h=20
# Bounding Box: x=1838, y=571, w=14, h=15
# Bounding Box: x=1785, y=568, w=19, h=18
# Bounding Box: x=1805, y=562, w=19, h=8
# Bounding Box: x=371, y=302, w=15, h=25
# Bounding Box: x=384, y=291, w=23, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=1839, y=572, w=13, h=13
# Bounding Box: x=1785, y=566, w=20, h=19
# Bounding Box: x=371, y=302, w=16, h=24
# Bounding Box: x=385, y=291, w=23, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=1840, y=571, w=13, h=13
# Bounding Box: x=1787, y=564, w=19, h=20
# Bounding Box: x=372, y=302, w=15, h=24
# Bounding Box: x=386, y=290, w=23, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=1826, y=579, w=15, h=10
# Bounding Box: x=1789, y=558, w=26, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=373, y=301, w=16, h=24
# Bounding Box: x=387, y=290, w=13, h=17
# Bounding Box: x=1842, y=572, w=12, h=11
# Bounding Box: x=1790, y=556, w=26, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=374, y=300, w=15, h=24
# Bounding Box: x=387, y=289, w=22, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=1792, y=554, w=26, h=25
# Snapshot saved: snapshot_2025-04-02_19-03-32.jpg
# Motion detected!
# Bounding Box: x=374, y=297, w=15, h=26
# Bounding Box: x=389, y=290, w=14, h=17
# Bounding Box: x=1843, y=572, w=12, h=12
# Bounding Box: x=1794, y=558, w=13, h=19
# Bounding Box: x=1806, y=551, w=14, h=12
# Bounding Box: x=403, y=319, w=13, h=13
# Bounding Box: x=375, y=294, w=14, h=28
# Bounding Box: x=390, y=289, w=21, h=21
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1825, y=566, w=13, h=11
# Bounding Box: x=1799, y=548, w=23, h=19
# Bounding Box: x=398, y=319, w=22, h=15
# Bounding Box: x=376, y=291, w=14, h=30
# Bounding Box: x=391, y=290, w=13, h=18
# Bounding Box: x=1845, y=572, w=12, h=12
# Bounding Box: x=1825, y=565, w=14, h=11
# Bounding Box: x=1805, y=545, w=20, h=22
# Bounding Box: x=398, y=319, w=27, h=16
# Bounding Box: x=377, y=291, w=14, h=30
# Bounding Box: x=392, y=289, w=13, h=19
# Bounding Box: x=1845, y=572, w=13, h=12
# Bounding Box: x=1805, y=542, w=36, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=401, y=319, w=27, h=16
# Bounding Box: x=378, y=290, w=14, h=30
# Bounding Box: x=393, y=289, w=13, h=19
# Bounding Box: x=1845, y=572, w=14, h=13
# Bounding Box: x=1806, y=540, w=34, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=404, y=320, w=28, h=14
# Bounding Box: x=379, y=288, w=35, h=33
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1852, y=543, w=13, h=11
# Bounding Box: x=1806, y=540, w=33, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=408, y=319, w=27, h=14
# Bounding Box: x=380, y=289, w=34, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1859, y=543, w=15, h=23
# Bounding Box: x=1808, y=541, w=30, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=381, y=289, w=34, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1866, y=545, w=14, h=33
# Bounding Box: x=1812, y=540, w=31, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=382, y=289, w=34, h=31
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1870, y=550, w=14, h=26
# Bounding Box: x=1817, y=540, w=32, h=24
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=384, y=288, w=34, h=33
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1821, y=540, w=33, h=33
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=385, y=288, w=34, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-33.jpg
# Motion detected!
# Bounding Box: x=1808, y=554, w=15, h=19
# Bounding Box: x=1867, y=546, w=11, h=17
# Bounding Box: x=1844, y=543, w=15, h=15
# Bounding Box: x=1825, y=542, w=19, h=30
# ...
# Snapshot saved: snapshot_2025-04-02_19-03-54.jpg
# Motion detected!
# Bounding Box: x=299, y=672, w=61, h=58
# Snapshot saved: snapshot_2025-04-02_19-03-54.jpg
# Motion detected!
# Bounding Box: x=1327, y=548, w=33, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-54.jpg
# Motion detected!
# Bounding Box: x=1315, y=538, w=24, h=16
# Bounding Box: x=297, y=680, w=52, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-54.jpg
# Motion detected!
# Bounding Box: x=1319, y=538, w=44, h=49
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=295, y=678, w=51, h=55
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1328, y=538, w=38, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=294, y=677, w=39, h=58
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1319, y=538, w=49, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=293, y=676, w=36, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1320, y=536, w=51, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=292, y=675, w=36, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1306, y=579, w=15, h=12
# Bounding Box: x=1323, y=535, w=51, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=314, y=724, w=18, h=12
# Bounding Box: x=290, y=673, w=38, h=49
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1306, y=578, w=20, h=13
# Bounding Box: x=1329, y=567, w=21, h=15
# Bounding Box: x=1339, y=533, w=39, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=290, y=671, w=41, h=66
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1307, y=533, w=75, h=57
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=289, y=669, w=41, h=65
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1314, y=533, w=72, h=54
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=288, y=666, w=44, h=64
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1321, y=533, w=69, h=51
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=287, y=663, w=45, h=62
# Snapshot saved: snapshot_2025-04-02_19-03-55.jpg
# Motion detected!
# Bounding Box: x=1331, y=534, w=63, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=286, y=660, w=45, h=59
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1333, y=534, w=65, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=285, y=658, w=45, h=62
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1334, y=534, w=67, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=284, y=655, w=44, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1118, y=605, w=12, h=12
# Bounding Box: x=1335, y=534, w=70, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=304, y=705, w=11, h=13
# Bounding Box: x=285, y=677, w=40, h=29
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=283, y=652, w=28, h=22
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1340, y=534, w=68, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=300, y=701, w=13, h=14
# Bounding Box: x=282, y=649, w=44, h=50
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1346, y=543, w=13, h=12
# Bounding Box: x=1359, y=533, w=52, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=281, y=647, w=35, h=65
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1354, y=530, w=60, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=281, y=644, w=36, h=64
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1364, y=528, w=53, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=280, y=641, w=37, h=60
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1366, y=527, w=54, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=280, y=637, w=38, h=57
# Snapshot saved: snapshot_2025-04-02_19-03-56.jpg
# Motion detected!
# Bounding Box: x=1368, y=527, w=55, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=280, y=632, w=39, h=54
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1368, y=526, w=58, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=280, y=621, w=40, h=55
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1369, y=526, w=60, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=280, y=625, w=41, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1370, y=525, w=61, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=280, y=620, w=42, h=48
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1372, y=526, w=61, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=298, y=664, w=12, h=13
# Bounding Box: x=280, y=616, w=43, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1368, y=526, w=68, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=281, y=609, w=47, h=66
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1368, y=526, w=70, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=283, y=609, w=41, h=63
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1370, y=528, w=70, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=284, y=606, w=47, h=60
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=1374, y=528, w=67, h=41
# Snapshot saved: snapshot_2025-04-02_19-03-57.jpg
# Motion detected!
# Bounding Box: x=287, y=602, w=41, h=56
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1379, y=551, w=12, h=15
# Bounding Box: x=1392, y=526, w=50, h=32
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=290, y=598, w=41, h=53
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1382, y=548, w=13, h=16
# Bounding Box: x=1399, y=524, w=45, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=293, y=594, w=40, h=49
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1386, y=546, w=12, h=14
# Bounding Box: x=1402, y=523, w=43, h=30
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=296, y=591, w=39, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1389, y=520, w=56, h=36
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=299, y=586, w=42, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1393, y=518, w=54, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=301, y=583, w=51, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1396, y=516, w=52, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=304, y=579, w=52, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1400, y=515, w=48, h=34
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=305, y=576, w=59, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1404, y=514, w=47, h=35
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=306, y=573, w=57, h=47
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1405, y=503, w=44, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=307, y=571, w=54, h=46
# Snapshot saved: snapshot_2025-04-02_19-03-58.jpg
# Motion detected!
# Bounding Box: x=1405, y=502, w=45, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=309, y=570, w=49, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1406, y=501, w=44, h=44
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=312, y=568, w=55, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1407, y=502, w=44, h=43
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=317, y=566, w=52, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1409, y=499, w=43, h=45
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=322, y=565, w=48, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1404, y=495, w=48, h=55
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=323, y=563, w=40, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1405, y=493, w=48, h=56
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=324, y=562, w=38, h=38
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1407, y=535, w=14, h=12
# Bounding Box: x=1413, y=492, w=41, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=325, y=560, w=36, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1410, y=532, w=13, h=12
# Bounding Box: x=1416, y=489, w=38, h=42
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=326, y=559, w=51, h=39
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1411, y=488, w=44, h=52
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=327, y=557, w=52, h=40
# Snapshot saved: snapshot_2025-04-02_19-03-59.jpg
# Motion detected!
# Bounding Box: x=1413, y=487, w=43, h=50
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=328, y=555, w=52, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1414, y=485, w=43, h=48
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=329, y=554, w=47, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1416, y=483, w=41, h=45
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=330, y=553, w=47, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1418, y=481, w=40, h=44
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=332, y=552, w=48, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1417, y=480, w=42, h=42
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=334, y=552, w=48, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1417, y=478, w=43, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=336, y=550, w=49, h=40
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1420, y=473, w=41, h=44
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=338, y=549, w=49, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1421, y=470, w=41, h=45
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=341, y=547, w=48, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1421, y=469, w=43, h=42
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=343, y=546, w=47, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-00.jpg
# Motion detected!
# Bounding Box: x=1421, y=468, w=43, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=345, y=545, w=46, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1421, y=468, w=45, h=40
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=347, y=543, w=45, h=40
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1422, y=466, w=45, h=40
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=349, y=541, w=44, h=41
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1422, y=465, w=47, h=37
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=350, y=540, w=48, h=40
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1413, y=502, w=11, h=13
# Bounding Box: x=1418, y=464, w=53, h=34
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=352, y=539, w=49, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1414, y=499, w=10, h=13
# Bounding Box: x=1424, y=461, w=49, h=34
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=353, y=538, w=53, h=38
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1425, y=458, w=47, h=35
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=355, y=537, w=51, h=38
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1416, y=486, w=11, h=17
# Bounding Box: x=1428, y=456, w=46, h=34
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=357, y=536, w=51, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1417, y=481, w=12, h=17
# Bounding Box: x=1420, y=454, w=56, h=34
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=359, y=535, w=50, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=1417, y=479, w=13, h=15
# Bounding Box: x=1422, y=451, w=55, h=35
# Snapshot saved: snapshot_2025-04-02_19-04-01.jpg
# Motion detected!
# Bounding Box: x=361, y=535, w=43, h=38
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=1418, y=474, w=12, h=14
# Bounding Box: x=1426, y=440, w=54, h=45
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=363, y=534, w=44, h=38
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=1420, y=443, w=61, h=40
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=365, y=533, w=44, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=1422, y=437, w=60, h=44
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=368, y=532, w=52, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=1434, y=432, w=48, h=47
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=370, y=531, w=53, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=1428, y=431, w=54, h=47
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=373, y=530, w=52, h=39
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
# Bounding Box: x=1430, y=430, w=53, h=47
# Snapshot saved: snapshot_2025-04-02_19-04-02.jpg
# Motion detected!
